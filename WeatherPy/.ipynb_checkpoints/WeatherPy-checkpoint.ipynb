# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %% [markdown]
# ---

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 619

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = ((city_weather['main']['temp_max'] - 273.15) * (9/5)) + 32
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tarauaca
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | waitangi
# Processing Record 6 of Set 1 | whitehorse
# Processing Record 7 of Set 1 | port lincoln
# Processing Record 8 of Set 1 | moranbah
# Processing Record 9 of Set 1 | berd
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | moss vale
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | kumylzhenskaya
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | blackmans bay
# Processing Record 18 of Set 1 | talnakh
# Processing Record 19 of Set 1 | fort bragg
# Processing Record 20 of Set 1 | galle
# Processing Record 21 of Set 1 | lata
# Processing Record 22 of Set 1 | grytviken
# Processing Record 23 of Set 1 | papao
# Processing Record 24 of Set 1 | fisterra
# Processing Record 25 of Set 1 | menaka
# Processing Record 26 of Set 1 | kawalu
# Processing Record 27 of Set 1 | lewistown
# Processing Record 28 of Set 1 | edinburgh of the seven seas
# Processing Record 29 of Set 1 | pokrovsk
# Processing Record 30 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 31 of Set 1 | tuban
# Processing Record 32 of Set 1 | sevastopol
# Processing Record 33 of Set 1 | greenville
# Processing Record 34 of Set 1 | port-aux-francais
# Processing Record 35 of Set 1 | hawaiian paradise park
# Processing Record 36 of Set 1 | tazovsky
# Processing Record 37 of Set 1 | pandan
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | cidreira
# Processing Record 40 of Set 1 | isafjordur
# Processing Record 41 of Set 1 | tofol
# Processing Record 42 of Set 1 | camaqua
# Processing Record 43 of Set 1 | coahuayana de hidalgo
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | utrik
# Processing Record 47 of Set 1 | vila franca do campo
# Processing Record 48 of Set 1 | cabo san lucas
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | akureyri
# Processing Record 0 of Set 2 | singaraja
# Processing Record 1 of Set 2 | izucar de matamoros
# Processing Record 2 of Set 2 | margaret river
# Processing Record 3 of Set 2 | luderitz
# Processing Record 4 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 5 of Set 2 | adamstown
# Processing Record 6 of Set 2 | stanley
# Processing Record 7 of Set 2 | ahau
# City not found. Skipping...
# Processing Record 8 of Set 2 | atakpame
# Processing Record 9 of Set 2 | zakynthos
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | qaqortoq
# Processing Record 12 of Set 2 | buckeye
# Processing Record 13 of Set 2 | tokar
# Processing Record 14 of Set 2 | gadzhiyevo
# Processing Record 15 of Set 2 | grootfontein
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | wailua homesteads
# Processing Record 18 of Set 2 | hun
# Processing Record 19 of Set 2 | nybro
# Processing Record 20 of Set 2 | hengchun
# Processing Record 21 of Set 2 | saipan
# Processing Record 22 of Set 2 | belozersk
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | bereket
# Processing Record 25 of Set 2 | rongelap
# Processing Record 26 of Set 2 | xinguara
# City not found. Skipping...
# Processing Record 27 of Set 2 | jatiroto
# Processing Record 28 of Set 2 | dazhou
# Processing Record 29 of Set 2 | wagar
# Processing Record 30 of Set 2 | papatowai
# Processing Record 31 of Set 2 | bilibino
# Processing Record 32 of Set 2 | invercargill
# Processing Record 33 of Set 2 | kittila
# Processing Record 34 of Set 2 | asasa
# Processing Record 35 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 36 of Set 2 | jiwani
# Processing Record 37 of Set 2 | ilulissat
# Processing Record 38 of Set 2 | iqaluit
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | cam ranh
# Processing Record 41 of Set 2 | enewetak
# Processing Record 42 of Set 2 | hadibu
# Processing Record 43 of Set 2 | colonia
# Processing Record 44 of Set 2 | el daein
# City not found. Skipping...
# Processing Record 45 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | zouerate
# Processing Record 48 of Set 2 | salinopolis
# Processing Record 49 of Set 2 | keflavik
# Processing Record 0 of Set 3 | olyokminsk
# Processing Record 1 of Set 3 | lompoc
# Processing Record 2 of Set 3 | holualoa
# Processing Record 3 of Set 3 | psedakh
# Processing Record 4 of Set 3 | fort mcmurray
# Processing Record 5 of Set 3 | sadovoye
# Processing Record 6 of Set 3 | caluula
# Processing Record 7 of Set 3 | sheoganj
# Processing Record 8 of Set 3 | kristiansund
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | constantia
# Processing Record 11 of Set 3 | jwaneng
# Processing Record 12 of Set 3 | behompy
# Processing Record 13 of Set 3 | sao joao da barra
# Processing Record 14 of Set 3 | iola
# Processing Record 15 of Set 3 | tralee
# Processing Record 16 of Set 3 | qorovulbozor
# Processing Record 17 of Set 3 | shanwei
# Processing Record 18 of Set 3 | aleg
# Processing Record 19 of Set 3 | ancud
# Processing Record 20 of Set 3 | salym
# Processing Record 21 of Set 3 | pisco
# Processing Record 22 of Set 3 | gornopravdinsk
# Processing Record 23 of Set 3 | mili
# Processing Record 24 of Set 3 | udachny
# Processing Record 25 of Set 3 | floro
# Processing Record 26 of Set 3 | puerto deseado
# Processing Record 27 of Set 3 | nikol'sk
# Processing Record 28 of Set 3 | plettenberg bay
# Processing Record 29 of Set 3 | beira
# Processing Record 30 of Set 3 | pechora
# Processing Record 31 of Set 3 | glace bay
# Processing Record 32 of Set 3 | ladnun
# Processing Record 33 of Set 3 | sittwe
# Processing Record 34 of Set 3 | ust-nera
# Processing Record 35 of Set 3 | tual
# Processing Record 36 of Set 3 | lihue
# Processing Record 37 of Set 3 | selkirk
# Processing Record 38 of Set 3 | ambajogai
# Processing Record 39 of Set 3 | pionerskiy
# Processing Record 40 of Set 3 | labrador city
# Processing Record 41 of Set 3 | chonchi
# Processing Record 42 of Set 3 | copiapo
# Processing Record 43 of Set 3 | ometepec
# Processing Record 44 of Set 3 | anadyr
# Processing Record 45 of Set 3 | tabou
# Processing Record 46 of Set 3 | severobaykal'sk
# Processing Record 47 of Set 3 | tura
# Processing Record 48 of Set 3 | kone
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 0 of Set 4 | badger
# Processing Record 1 of Set 4 | ust'-uda
# Processing Record 2 of Set 4 | west island
# Processing Record 3 of Set 4 | pangody
# Processing Record 4 of Set 4 | hithadhoo
# Processing Record 5 of Set 4 | betio village
# Processing Record 6 of Set 4 | nuuk
# Processing Record 7 of Set 4 | fuglafjordur
# Processing Record 8 of Set 4 | izumiotsu
# Processing Record 9 of Set 4 | puerto baquerizo moreno
# Processing Record 10 of Set 4 | nar'yan-mar
# Processing Record 11 of Set 4 | gizo
# Processing Record 12 of Set 4 | la passe
# Processing Record 13 of Set 4 | san justo
# Processing Record 14 of Set 4 | malmberget
# Processing Record 15 of Set 4 | college
# Processing Record 16 of Set 4 | olonkinbyen
# Processing Record 17 of Set 4 | itoman
# Processing Record 18 of Set 4 | longyearbyen
# Processing Record 19 of Set 4 | sandnessjoen
# Processing Record 20 of Set 4 | zapadnaya dvina
# Processing Record 21 of Set 4 | barah
# Processing Record 22 of Set 4 | phulbani
# Processing Record 23 of Set 4 | al kharijah
# Processing Record 24 of Set 4 | puerto natales
# Processing Record 25 of Set 4 | cururupu
# Processing Record 26 of Set 4 | selfoss
# Processing Record 27 of Set 4 | burang
# Processing Record 28 of Set 4 | mogocha
# Processing Record 29 of Set 4 | verkhnevilyuysk
# Processing Record 30 of Set 4 | atafu village
# Processing Record 31 of Set 4 | al-`ula
# City not found. Skipping...
# Processing Record 32 of Set 4 | piti village
# Processing Record 33 of Set 4 | talcher
# Processing Record 34 of Set 4 | freetown
# Processing Record 35 of Set 4 | znamenskoye
# Processing Record 36 of Set 4 | jagraon
# Processing Record 37 of Set 4 | aasiaat
# Processing Record 38 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 39 of Set 4 | kailua-kona
# Processing Record 40 of Set 4 | kavaratti
# Processing Record 41 of Set 4 | georgetown
# Processing Record 42 of Set 4 | slave lake
# Processing Record 43 of Set 4 | kupang
# Processing Record 44 of Set 4 | ugoofaaru
# Processing Record 45 of Set 4 | paradip garh
# Processing Record 46 of Set 4 | cranbrook
# Processing Record 47 of Set 4 | nemuro
# Processing Record 48 of Set 4 | lazaro cardenas
# Processing Record 49 of Set 4 | milford haven
# Processing Record 0 of Set 5 | babruysk
# Processing Record 1 of Set 5 | weno
# Processing Record 2 of Set 5 | greymouth
# Processing Record 3 of Set 5 | tolanaro
# Processing Record 4 of Set 5 | la ronge
# Processing Record 5 of Set 5 | praia da vitoria
# Processing Record 6 of Set 5 | churu
# Processing Record 7 of Set 5 | ola
# Processing Record 8 of Set 5 | stratford-upon-avon
# Processing Record 9 of Set 5 | soure
# Processing Record 10 of Set 5 | tucupita
# Processing Record 11 of Set 5 | juan griego
# Processing Record 12 of Set 5 | vadso
# Processing Record 13 of Set 5 | zhanaozen
# Processing Record 14 of Set 5 | dauphin
# Processing Record 15 of Set 5 | port alfred
# Processing Record 16 of Set 5 | al bawiti
# Processing Record 17 of Set 5 | damboa
# Processing Record 18 of Set 5 | siwa oasis
# Processing Record 19 of Set 5 | jalai nur
# Processing Record 20 of Set 5 | melito di porto salvo
# Processing Record 21 of Set 5 | am timan
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | maracana
# Processing Record 24 of Set 5 | santa marta de ortigueira
# Processing Record 25 of Set 5 | nieuw amsterdam
# Processing Record 26 of Set 5 | mangrol
# Processing Record 27 of Set 5 | tvoroyri
# Processing Record 28 of Set 5 | sinop
# Processing Record 29 of Set 5 | vohimanitra
# City not found. Skipping...
# Processing Record 30 of Set 5 | nema
# Processing Record 31 of Set 5 | hamilton
# Processing Record 32 of Set 5 | urengoy
# Processing Record 33 of Set 5 | bechar
# Processing Record 34 of Set 5 | ujae
# Processing Record 35 of Set 5 | iskateley
# Processing Record 36 of Set 5 | badiyah
# Processing Record 37 of Set 5 | vorgashor
# Processing Record 38 of Set 5 | crixas
# Processing Record 39 of Set 5 | arawa
# Processing Record 40 of Set 5 | callao
# Processing Record 41 of Set 5 | bururi
# Processing Record 42 of Set 5 | viljoenskroon
# Processing Record 43 of Set 5 | orapa
# Processing Record 44 of Set 5 | yasinya
# Processing Record 45 of Set 5 | dudinka
# Processing Record 46 of Set 5 | arteche
# Processing Record 47 of Set 5 | barcelos
# Processing Record 48 of Set 5 | borogontsy
# Processing Record 49 of Set 5 | zhosaly
# Processing Record 0 of Set 6 | vilyuchinsk
# Processing Record 1 of Set 6 | dinguiraye
# Processing Record 2 of Set 6 | kayes
# Processing Record 3 of Set 6 | port-vila
# Processing Record 4 of Set 6 | susuman
# Processing Record 5 of Set 6 | ust'-ilimsk
# Processing Record 6 of Set 6 | campo gallo
# Processing Record 7 of Set 6 | nadym
# Processing Record 8 of Set 6 | mizusawa
# Processing Record 9 of Set 6 | rawson
# Processing Record 10 of Set 6 | santa elena de uairen
# Processing Record 11 of Set 6 | bambanglipuro
# Processing Record 12 of Set 6 | kingston
# Processing Record 13 of Set 6 | kendari
# Processing Record 14 of Set 6 | tiruchchendur
# Processing Record 15 of Set 6 | olds
# Processing Record 16 of Set 6 | san patricio
# Processing Record 17 of Set 6 | san antonio de pale
# Processing Record 18 of Set 6 | krizevci
# Processing Record 19 of Set 6 | ihosy
# Processing Record 20 of Set 6 | nadi
# Processing Record 21 of Set 6 | dikhil
# Processing Record 22 of Set 6 | bouar
# Processing Record 23 of Set 6 | zyrya
# Processing Record 24 of Set 6 | lebu
# Processing Record 25 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 26 of Set 6 | bridgewater
# Processing Record 27 of Set 6 | maych'ew
# Processing Record 28 of Set 6 | fort saskatchewan
# Processing Record 29 of Set 6 | launceston
# Processing Record 30 of Set 6 | lyantor
# Processing Record 31 of Set 6 | bikenibeu village
# Processing Record 32 of Set 6 | marksville
# Processing Record 33 of Set 6 | porto novo
# Processing Record 34 of Set 6 | klyuchi
# Processing Record 35 of Set 6 | dalbandin
# Processing Record 36 of Set 6 | ambovombe
# Processing Record 37 of Set 6 | hamlin
# Processing Record 38 of Set 6 | alofi
# Processing Record 39 of Set 6 | bogo
# Processing Record 40 of Set 6 | namibe
# Processing Record 41 of Set 6 | nguigmi
# Processing Record 42 of Set 6 | gueret
# Processing Record 43 of Set 6 | port saint john's
# Processing Record 44 of Set 6 | stephenville
# Processing Record 45 of Set 6 | remire-montjoly
# Processing Record 46 of Set 6 | richards bay
# Processing Record 47 of Set 6 | umm kaddadah
# Processing Record 48 of Set 6 | walvis bay
# Processing Record 49 of Set 6 | pacific grove
# Processing Record 0 of Set 7 | sur
# Processing Record 1 of Set 7 | gilgit
# Processing Record 2 of Set 7 | chulym
# Processing Record 3 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 4 of Set 7 | berezovyy
# Processing Record 5 of Set 7 | malango
# Processing Record 6 of Set 7 | katsuura
# Processing Record 7 of Set 7 | fort st. john
# Processing Record 8 of Set 7 | ahmadpur sial
# Processing Record 9 of Set 7 | diego de almagro
# Processing Record 10 of Set 7 | sanya
# Processing Record 11 of Set 7 | barrouallie
# Processing Record 12 of Set 7 | karymskoye
# Processing Record 13 of Set 7 | port mathurin
# Processing Record 14 of Set 7 | santiago
# Processing Record 15 of Set 7 | bajina basta
# Processing Record 16 of Set 7 | jayapura
# Processing Record 17 of Set 7 | singkil
# Processing Record 18 of Set 7 | christchurch
# Processing Record 19 of Set 7 | fedorovskiy
# Processing Record 20 of Set 7 | wainwright
# Processing Record 21 of Set 7 | egilsstadir
# Processing Record 22 of Set 7 | port augusta
# Processing Record 23 of Set 7 | messaad
# Processing Record 24 of Set 7 | taroa
# Processing Record 25 of Set 7 | mukah
# City not found. Skipping...
# Processing Record 26 of Set 7 | backi petrovac
# Processing Record 27 of Set 7 | medak
# Processing Record 28 of Set 7 | adrar
# Processing Record 29 of Set 7 | pontes e lacerda
# Processing Record 30 of Set 7 | igbo-ora
# Processing Record 31 of Set 7 | gilford
# Processing Record 32 of Set 7 | hotan
# Processing Record 33 of Set 7 | piacabucu
# Processing Record 34 of Set 7 | severo-yeniseyskiy
# Processing Record 35 of Set 7 | yilan
# Processing Record 36 of Set 7 | savannakhet
# Processing Record 37 of Set 7 | kovdor
# Processing Record 38 of Set 7 | bontang
# Processing Record 39 of Set 7 | cabedelo
# Processing Record 40 of Set 7 | sidney
# Processing Record 41 of Set 7 | dhidhdhoo
# Processing Record 42 of Set 7 | santiago de cao
# Processing Record 43 of Set 7 | aksu
# Processing Record 44 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 45 of Set 7 | miramichi
# Processing Record 46 of Set 7 | yarmouth
# Processing Record 47 of Set 7 | quellon
# Processing Record 48 of Set 7 | new norfolk
# Processing Record 49 of Set 7 | nogliki
# Processing Record 0 of Set 8 | eyl
# Processing Record 1 of Set 8 | sakakah
# Processing Record 2 of Set 8 | crane
# Processing Record 3 of Set 8 | inyonga
# Processing Record 4 of Set 8 | bairnsdale
# Processing Record 5 of Set 8 | raton
# Processing Record 6 of Set 8 | palu
# Processing Record 7 of Set 8 | balkanabat
# Processing Record 8 of Set 8 | northam
# Processing Record 9 of Set 8 | fort carson
# Processing Record 10 of Set 8 | slonim
# Processing Record 11 of Set 8 | ulsteinvik
# Processing Record 12 of Set 8 | haiku-pauwela
# Processing Record 13 of Set 8 | aykhal
# Processing Record 14 of Set 8 | canico
# Processing Record 15 of Set 8 | san andros
# City not found. Skipping...
# Processing Record 16 of Set 8 | mundri
# Processing Record 17 of Set 8 | pauini
# Processing Record 18 of Set 8 | manado
# Processing Record 19 of Set 8 | as sulayyil
# Processing Record 20 of Set 8 | victoria
# Processing Record 21 of Set 8 | vila do maio
# Processing Record 22 of Set 8 | yemva
# Processing Record 23 of Set 8 | polyarnyy
# Processing Record 24 of Set 8 | checker hall
# City not found. Skipping...
# Processing Record 25 of Set 8 | fairview
# Processing Record 26 of Set 8 | imbituba
# Processing Record 27 of Set 8 | port blair
# Processing Record 28 of Set 8 | okhotsk
# Processing Record 29 of Set 8 | pakxan
# Processing Record 30 of Set 8 | tefe
# Processing Record 31 of Set 8 | agropoli
# Processing Record 32 of Set 8 | esqueda
# Processing Record 33 of Set 8 | hailey
# Processing Record 34 of Set 8 | gulf shores
# Processing Record 35 of Set 8 | marsabit
# Processing Record 36 of Set 8 | hovd
# Processing Record 37 of Set 8 | chegdomyn
# Processing Record 38 of Set 8 | mirny
# Processing Record 39 of Set 8 | acarau
# Processing Record 40 of Set 8 | sao vicente
# Processing Record 41 of Set 8 | vershino-darasunskiy
# Processing Record 42 of Set 8 | baikonur
# Processing Record 43 of Set 8 | xuanzhou
# Processing Record 44 of Set 8 | selma
# Processing Record 45 of Set 8 | east london
# Processing Record 46 of Set 8 | bealanana
# Processing Record 47 of Set 8 | hawick
# Processing Record 48 of Set 8 | vila velha
# Processing Record 49 of Set 8 | shingu
# Processing Record 0 of Set 9 | tsiombe
# Processing Record 1 of Set 9 | banda aceh
# Processing Record 2 of Set 9 | choyr
# Processing Record 3 of Set 9 | inari
# Processing Record 4 of Set 9 | novobureyskiy
# Processing Record 5 of Set 9 | okakarara
# Processing Record 6 of Set 9 | country club estates
# Processing Record 7 of Set 9 | hastings
# Processing Record 8 of Set 9 | sechura
# Processing Record 9 of Set 9 | kapa'a
# Processing Record 10 of Set 9 | sanjwal
# Processing Record 11 of Set 9 | masterton
# Processing Record 12 of Set 9 | kiunga
# Processing Record 13 of Set 9 | ndende
# Processing Record 14 of Set 9 | plymouth
# Processing Record 15 of Set 9 | myeik
# Processing Record 16 of Set 9 | mount isa
# Processing Record 17 of Set 9 | coronel moldes
# Processing Record 18 of Set 9 | levuka
# Processing Record 19 of Set 9 | yuzhno-kurilsk
# Processing Record 20 of Set 9 | tazacorte
# Processing Record 21 of Set 9 | tobol'sk
# Processing Record 22 of Set 9 | kencong
# Processing Record 23 of Set 9 | murzuq
# Processing Record 24 of Set 9 | dubbo
# Processing Record 25 of Set 9 | aden
# Processing Record 26 of Set 9 | saint-joseph
# Processing Record 27 of Set 9 | mbuji-mayi
# Processing Record 28 of Set 9 | cockburn town
# Processing Record 29 of Set 9 | sanctuary point
# Processing Record 30 of Set 9 | gidole
# Processing Record 31 of Set 9 | ipatovo
# Processing Record 32 of Set 9 | rogers park
# Processing Record 33 of Set 9 | howrah
# Processing Record 34 of Set 9 | fortuna
# Processing Record 35 of Set 9 | puerto san jose
# Processing Record 36 of Set 9 | flying fish cove
# Processing Record 37 of Set 9 | margate
# Processing Record 38 of Set 9 | saldanha
# Processing Record 39 of Set 9 | turabah
# Processing Record 40 of Set 9 | onega
# Processing Record 41 of Set 9 | kapuskasing
# Processing Record 42 of Set 9 | happy valley-goose bay
# Processing Record 43 of Set 9 | saint-philippe
# Processing Record 44 of Set 9 | semnan
# Processing Record 45 of Set 9 | collinsville
# Processing Record 46 of Set 9 | trujillo
# Processing Record 47 of Set 9 | mujiayingzi
# Processing Record 48 of Set 9 | mukalla
# Processing Record 49 of Set 9 | lincoln
# Processing Record 0 of Set 10 | aitape
# Processing Record 1 of Set 10 | carqueiranne
# Processing Record 2 of Set 10 | st. john's
# Processing Record 3 of Set 10 | pustoshka
# Processing Record 4 of Set 10 | mamfe
# Processing Record 5 of Set 10 | lucas
# Processing Record 6 of Set 10 | touros
# Processing Record 7 of Set 10 | harper
# Processing Record 8 of Set 10 | nova sintra
# Processing Record 9 of Set 10 | yaren
# Processing Record 10 of Set 10 | neon karlovasion
# Processing Record 11 of Set 10 | kangding
# Processing Record 12 of Set 10 | nuku'alofa
# Processing Record 13 of Set 10 | pangobilian
# Processing Record 14 of Set 10 | caleta de carquin
# Processing Record 15 of Set 10 | afaahiti
# Processing Record 16 of Set 10 | taulaga
# Processing Record 17 of Set 10 | newman
# Processing Record 18 of Set 10 | siniscola
# Processing Record 19 of Set 10 | istgah-e rah ahan-e garmsar
# Processing Record 20 of Set 10 | brisas de zicatela
# Processing Record 21 of Set 10 | oualidia
# City not found. Skipping...
# Processing Record 22 of Set 10 | tatarsk
# Processing Record 23 of Set 10 | watford city
# Processing Record 24 of Set 10 | adel
# Processing Record 25 of Set 10 | warrenpoint
# Processing Record 26 of Set 10 | bonthe
# Processing Record 27 of Set 10 | jerantut
# Processing Record 28 of Set 10 | indianola
# Processing Record 29 of Set 10 | kenai
# Processing Record 30 of Set 10 | shitanjing
# Processing Record 31 of Set 10 | shimo-furano
# Processing Record 32 of Set 10 | sirte
# Processing Record 33 of Set 10 | kununurra
# Processing Record 34 of Set 10 | holdrege
# Processing Record 35 of Set 10 | konarka
# Processing Record 36 of Set 10 | sturgis
# Processing Record 37 of Set 10 | tucurui
# Processing Record 38 of Set 10 | mossel bay
# Processing Record 39 of Set 10 | kuna
# Processing Record 40 of Set 10 | nemencine
# Processing Record 41 of Set 10 | kourou
# Processing Record 42 of Set 10 | sitia
# Processing Record 43 of Set 10 | nova vicosa
# Processing Record 44 of Set 10 | puerto aysen
# Processing Record 45 of Set 10 | baishishan
# Processing Record 46 of Set 10 | necochea
# Processing Record 47 of Set 10 | cold springs
# Processing Record 48 of Set 10 | carutapera
# Processing Record 49 of Set 10 | urangan
# Processing Record 0 of Set 11 | nyons
# Processing Record 1 of Set 11 | el fasher
# Processing Record 2 of Set 11 | bandarbeyla
# Processing Record 3 of Set 11 | suva
# Processing Record 4 of Set 11 | waingapu
# Processing Record 5 of Set 11 | dickinson
# Processing Record 6 of Set 11 | namsos
# Processing Record 7 of Set 11 | bodo
# Processing Record 8 of Set 11 | half moon bay
# Processing Record 9 of Set 11 | boyolangu
# Processing Record 10 of Set 11 | trincomalee
# Processing Record 11 of Set 11 | magadan
# Processing Record 12 of Set 11 | abra pampa
# Processing Record 13 of Set 11 | kshenskiy
# Processing Record 14 of Set 11 | paraiba do sul
# Processing Record 15 of Set 11 | iranshahr
# Processing Record 16 of Set 11 | opuwo
# Processing Record 17 of Set 11 | vilyuysk
# Processing Record 18 of Set 11 | nikolayevsk-on-amure
# Processing Record 19 of Set 11 | phan rang-thap cham
# Processing Record 20 of Set 11 | kurduvadi
# Processing Record 21 of Set 11 | ebon
# Processing Record 22 of Set 11 | purpe
# Processing Record 23 of Set 11 | plastun
# Processing Record 24 of Set 11 | island harbour
# Processing Record 25 of Set 11 | cole harbour
# Processing Record 26 of Set 11 | mikuni
# Processing Record 27 of Set 11 | priargunsk
# Processing Record 28 of Set 11 | fale old settlement
# Processing Record 29 of Set 11 | tukrah
# Processing Record 30 of Set 11 | mar del plata
# Processing Record 31 of Set 11 | kayangel
# Processing Record 32 of Set 11 | katy wroclawskie
# Processing Record 33 of Set 11 | salekhard
# Processing Record 34 of Set 11 | yanggu
# Processing Record 35 of Set 11 | sorong
# Processing Record 36 of Set 11 | sultanah
# Processing Record 37 of Set 11 | hilo
# Processing Record 38 of Set 11 | danville
# Processing Record 39 of Set 11 | amahai
# City not found. Skipping...
# Processing Record 40 of Set 11 | chui
# Processing Record 41 of Set 11 | taco pozo
# Processing Record 42 of Set 11 | vaskelovo
# Processing Record 43 of Set 11 | kalispell
# Processing Record 44 of Set 11 | guane
# Processing Record 45 of Set 11 | uklana
# Processing Record 46 of Set 11 | saint-paul
# Processing Record 47 of Set 11 | ulanhot
# Processing Record 48 of Set 11 | alice springs
# Processing Record 49 of Set 11 | la'ie
# Processing Record 0 of Set 12 | boise
# Processing Record 1 of Set 12 | loa janan
# Processing Record 2 of Set 12 | barbacoas
# Processing Record 3 of Set 12 | queenstown
# Processing Record 4 of Set 12 | westport
# Processing Record 5 of Set 12 | sao gabriel da cachoeira
# Processing Record 6 of Set 12 | sitka
# Processing Record 7 of Set 12 | bengkulu
# Processing Record 8 of Set 12 | adelaide
# Processing Record 9 of Set 12 | merida
# Processing Record 10 of Set 12 | sakaiminato
# Processing Record 11 of Set 12 | nishinoomote
# Processing Record 12 of Set 12 | coffs harbour
# Processing Record 13 of Set 12 | kavieng
# Processing Record 14 of Set 12 | machico
# Processing Record 15 of Set 12 | adra
# Processing Record 16 of Set 12 | sri dungargarh
# Processing Record 17 of Set 12 | budva
# Processing Record 18 of Set 12 | yelizovo
# Processing Record 19 of Set 12 | houma
# Processing Record 20 of Set 12 | yylanly
# City not found. Skipping...
# Processing Record 21 of Set 12 | ilhabela
# Processing Record 22 of Set 12 | guanica
# Processing Record 23 of Set 12 | arrifes
# Processing Record 24 of Set 12 | hlinsko
# Processing Record 25 of Set 12 | isangel
# Processing Record 26 of Set 12 | ciales
# Processing Record 27 of Set 12 | cheremukhovo
# Processing Record 28 of Set 12 | mizan teferi
# Processing Record 29 of Set 12 | prainha
# Processing Record 30 of Set 12 | mokhsogollokh
# Processing Record 31 of Set 12 | giarmata
# Processing Record 32 of Set 12 | lerwick
# Processing Record 33 of Set 12 | santa luzia
# Processing Record 34 of Set 12 | sassandra
# Processing Record 35 of Set 12 | pijijiapan
# Processing Record 36 of Set 12 | lamu
# Processing Record 37 of Set 12 | jieshi
# Processing Record 38 of Set 12 | ostersund
# Processing Record 39 of Set 12 | twentynine palms
# Processing Record 40 of Set 12 | zhaqsy
# Processing Record 41 of Set 12 | san sebastian de la gomera
# Processing Record 42 of Set 12 | kombissiri
# Processing Record 43 of Set 12 | brainerd
# Processing Record 44 of Set 12 | el granada
# Processing Record 45 of Set 12 | awash
# Processing Record 46 of Set 12 | taza
# Processing Record 47 of Set 12 | menongue
# Processing Record 48 of Set 12 | fonadhoo
# City not found. Skipping...
# Processing Record 49 of Set 12 | flin flon
# Processing Record 0 of Set 13 | taltal
# Processing Record 1 of Set 13 | taoudenni
# Processing Record 2 of Set 13 | beloyarskiy
# Processing Record 3 of Set 13 | benjamin aceval
# Processing Record 4 of Set 13 | quang ngai
# Processing Record 5 of Set 13 | morondava
# Processing Record 6 of Set 13 | tobi village
# City not found. Skipping...
# Processing Record 7 of Set 13 | inhambane
# Processing Record 8 of Set 13 | palmer
# Processing Record 9 of Set 13 | qui nhon
# Processing Record 10 of Set 13 | sint-martens-latem
# Processing Record 11 of Set 13 | alpena
# Processing Record 12 of Set 13 | bohodukhiv
# Processing Record 13 of Set 13 | balaipungut
# Processing Record 14 of Set 13 | souillac
# Processing Record 15 of Set 13 | bafq
# Processing Record 16 of Set 13 | trebic
# Processing Record 17 of Set 13 | sarakhs
# Processing Record 18 of Set 13 | luanda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          599
# Lat           599
# Lng           599
# Max Temp      599
# Humidity      599
# Cloudiness    599
# Wind Speed    599
# Country       599
# Date          599
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        tarauaca  -8.1614  -70.7656    72.734        99          30
# 1           tiksi  71.6872  128.8694    31.136        75          23
# 2  ribeira grande  38.5167  -28.7000    64.778        84          10
# 3       carnarvon -24.8667  113.6333    69.746        67           0
# 4        waitangi -43.9535 -176.5597    58.820        97         100
#
#    Wind Speed Country        Date
# 0        1.15      BR  1685494427
# 1        1.22      RU  1685494427
# 2        5.36      PT  1685494428
# 3        1.96      AU  1685494428
# 4        0.89      NZ  1685494429

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              tarauaca  -8.1614  -70.7656    72.734        99          30
# 1                 tiksi  71.6872  128.8694    31.136        75          23
# 2        ribeira grande  38.5167  -28.7000    64.778        84          10
# 3             carnarvon -24.8667  113.6333    69.746        67           0
# 4              waitangi -43.9535 -176.5597    58.820        97         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.15      BR  1685494427
# 1              1.22      RU  1685494427
# 2              5.36      PT  1685494428
# 3              1.96      AU  1685494428
# 4              0.89      NZ  1685494429

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter",x="Lat",y="Max Temp",s=40,marker ="o",facecolor="blue",edgecolor ="k",grid=True, figsize=(8,6),\
                  xlabel = "Latitude", ylabel = "Max Temperature(C)", title = f"City Latitude Vs. Max Temperature" ) 

# Incorporate the other graph properties

xmin = city_data_df["Lat"].min() - 10
xmax=city_data_df["Lat"].max() + 10
ymin=city_data_df["Max Temp"].min()- 0.1 * (city_data_df["Max Temp"].max()-city_data_df["Max Temp"].min())
ymax=city_data_df["Max Temp"].max()+ 0.1 * (city_data_df["Max Temp"].max()-city_data_df["Max Temp"].min())
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter",x="Lat",y="Humidity",s=40,marker ="o",facecolor="blue",edgecolor ="k",grid=True, figsize=(8,6),\
                  xlabel = "Latitude", ylabel = "Humidity(%)", title = f"City Latitude Vs. Humidity" ) 


# Incorporate the other graph properties
xmin = city_data_df["Lat"].min() - 10
xmax=city_data_df["Lat"].max() + 10
ymin=city_data_df["Humidity"].min()- 0.1 * (city_data_df["Humidity"].max()-city_data_df["Humidity"].min())
ymax=city_data_df["Humidity"].max()+ 0.1 * (city_data_df["Humidity"].max()-city_data_df["Humidity"].min())
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind="scatter",x="Lat",y="Cloudiness",s=40,marker ="o",facecolor="blue",edgecolor ="k",grid=True, figsize=(8,6),\
                  xlabel = "Latitude", ylabel = "Cloudiness(%)", title = f"City Latitude Vs. Cloudiness" ) 


# Incorporate the other graph properties
xmin = city_data_df["Lat"].min() - 10
xmax=city_data_df["Lat"].max() + 10
ymin=city_data_df["Cloudiness"].min()- 0.1 * (city_data_df["Cloudiness"].max()-city_data_df["Cloudiness"].min())
ymax=city_data_df["Cloudiness"].max()+ 0.1 * (city_data_df["Cloudiness"].max()-city_data_df["Cloudiness"].min())
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind="scatter",x="Lat",y="Wind Speed",s=40,marker ="o",facecolor="blue",edgecolor ="k",grid=True, figsize=(8,6),\
                  xlabel = "Latitude", ylabel = "Wind Speed(m/s)", title = f"City Latitude Vs. Wind Speed" ) 


# Incorporate the other graph properties
xmin = city_data_df["Lat"].min() - 10
xmax=city_data_df["Lat"].max() + 10
ymin=city_data_df["Wind Speed"].min()- 0.1 * (city_data_df["Wind Speed"].max()-city_data_df["Wind Speed"].min())
ymax=city_data_df["Wind Speed"].max()+ 0.1 * (city_data_df["Wind Speed"].max()-city_data_df["Wind Speed"].min())
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_scatters(Dataframe,X_Column,Y_Column_List,Hemispheres):

    for i,Y_Column in enumerate(Y_Column_List):
        
        for h,hem in enumerate(Hemispheres):
        
                if h==0:
                    plot_df =  Dataframe.loc[Dataframe[X_Column]>= 0,[X_Column,Y_Column]].reset_index(drop=True)
                    plot_df.plot(kind="scatter",x=X_Column,y=Y_Column,s=40,marker ="o",color="blue",edgecolor ="k",grid=True, figsize=(8,6),\
                    xlabel = "Latitude", ylabel = f"{Y_Column}") 
                    font = {'color':  'blue','fontweight': '3','fontsize': 14}    

                else:
                    plot_df =  Dataframe.loc[Dataframe[X_Column]< 0,[X_Column,Y_Column]].reset_index(drop=True)
                    plot_df.plot(kind="scatter",x=X_Column,y=Y_Column,s=40,marker ="o",color="green",edgecolor ="k",grid=True, figsize=(8,6),\
                    xlabel = "Latitude", ylabel = f"{Y_Column}") 
                    font = {'color':  'green','fontweight': '3','fontsize': 14}    
                
                plt.title(f"{hem}: Latitude Vs. {Y_Column}",fontdict=font)  
                
                xaxis = plot_df[X_Column]
                yaxis =  plot_df[Y_Column]
                
                xmin = xaxis.min() - 10
                xmax=xaxis.max() + 10
                ymin=yaxis.min()- 0.1 * (yaxis.max()-yaxis.min())
                ymax=yaxis.max()+ 0.1 * (yaxis.max()-yaxis.min())
                plt.xlim(xmin,xmax)
                plt.ylim(ymin,ymax)

                (slope, intercept, r, p, std_e) = st.linregress(xaxis,yaxis)
                regress_line = (slope * xaxis) + intercept
                regress_eq = "Y = " + str(round(slope,2))+ "* X + " + str(round(intercept,2))

                plt.plot(xaxis,regress_line,color = "r")
                plt.annotate(regress_eq,xy=(xmin+((xmax - xmin)/2),yaxis.min()- 0.08 * (yaxis.max()-yaxis.min())),color="r",fontsize=14)
                plt.annotate(f"The R-Squared Value is: {round(r,2)}",xy=(xmin,yaxis.min()- 0.08 * (yaxis.max()-yaxis.min())),color="r",fontsize=14)
                plt.tight_layout()


Hemispheres = ["Northern Hemisphere", "Southern Hemisphere"]
y_col_list = ["Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
plot_scatters(city_data_df,"Lat",y_col_list,Hemispheres)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df =  city_data_df.loc[city_data_df["Lat"]>= 0,:].reset_index(drop=True)

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           tiksi  71.6872  128.8694    31.136        75          23
# 1  ribeira grande  38.5167  -28.7000    64.778        84          10
# 2      whitehorse  60.7161 -135.0538    52.808        32          75
# 3            berd  40.8815   45.3899    60.332        70          39
# 4       jamestown  42.0970  -79.2353    78.386        50         100
#
#    Wind Speed Country        Date
# 0        1.22      RU  1685494427
# 1        5.36      PT  1685494428
# 2        5.14      CA  1685494429
# 3        3.79      AM  1685494430
# 4        2.57      US  1685494432

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df =  city_data_df.loc[city_data_df["Lat"]< 0,:].reset_index(drop=True)

# Display sample data
southern_hemi_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      tarauaca  -8.1614  -70.7656    72.734        99          30
# 1     carnarvon -24.8667  113.6333    69.746        67           0
# 2      waitangi -43.9535 -176.5597    58.820        97         100
# 3  port lincoln -34.7333  135.8667    66.110        59          90
# 4      moranbah -22.0016  148.0466    69.548        54           0
#
#    Wind Speed Country        Date
# 0        1.15      BR  1685494427
# 1        1.96      AU  1685494428
# 2        0.89      NZ  1685494429
# 3        8.24      AU  1685494429
# 4        7.51      AU  1685494401

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# ALL PLOTS WERE CREATED IN A SINGLE FUNCTION ABOVE - IT FOLLOWS THE SAME ORDER EXPECTED HERE

# %% [markdown]
# **Discussion about the linear relationship:**
# There is a high correlation (R-Square) of greater than 75% between max temperature and latitude - in both Northern and Souther Hemispheres
#
# In the Southern Hemisphere the relationship is linear and positive ie. - as we move towards the equator and the latitude increases, there is an increase in max temperature.
#
# In the Northern Hemisphere the relationship is linear and negative ie. - as we move towards the equator and the latitude decreases, there is an increase in max temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# ALL PLOTS WERE CREATED IN A SINGLE FUNCTION ABOVE - IT FOLLOWS THE SAME ORDER EXPECTED HERE

# %% [markdown]
# **Discussion about the linear relationship:** There is a very low correlation (R-Square) between latitude and humidity in both Northern(-1%) and Southern(11%) Hemispheres. Hence we can conclude there is no linear relationship.
#
# Just an observation outside of linear regression - the scatter plot shows that in the Southern Hemisphere, there are higher number of humid cities closer to the equator (latitude = 0)

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# ALL PLOTS WERE CREATED IN A SINGLE FUNCTION ABOVE - IT FOLLOWS THE SAME ORDER EXPECTED HERE

# %% [markdown]
# **Discussion about the linear relationship:** There is a negative correlation (R-Square) between latitude and cloudiness but it is very low at -12% in Southern and -4% in Northern Hemispheres. Hence we can conclude there is no linear relationship.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# ALL PLOTS WERE CREATED IN A SINGLE FUNCTION ABOVE - IT FOLLOWS THE SAME ORDER EXPECTED HERE

# %% [markdown]
# **Discussion about the linear relationship:**
# There is a very low positive correlation (R-Square) of 17% between latitude and Wind Speed - in the Northern Hemisphere
#
# There is a very low negative correlation (R-Square) of -26% between latitude and Wind Speed - in the Southern Hemisphere
#
# So as we move towards the equator the Wind Speed decreases - but the R-Square is too low to conclude a linear relationship.
